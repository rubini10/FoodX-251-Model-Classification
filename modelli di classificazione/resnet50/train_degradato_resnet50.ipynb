# %%
import tarfile
import zipfile
import shutil
import random
import os
import cv2
import pathlib
import numpy as np
import pandas as pd

import tensorflow as tf
import matplotlib.pyplot as plt
from numpy.random import seed
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import mixed_precision
from tensorflow.keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet import ResNet101



from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import top_k_accuracy_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

import plotly.graph_objects as go
from plotly.subplots import make_subplots

from tqdm.notebook import tqdm
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
random_seed = 42
keras.utils.set_random_seed(random_seed)

# %%
train_data_dir = pathlib.Path('/kaggle/input/foodx-251/clean_train80_sampling_degradato_diviso/clean_train80_sampling_degradato_diviso')
shuffle_value = True
validation_split = 0.2
batch_size = 256
seed_train_validation = 42

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    labels="inferred",
    label_mode="categorical",
    validation_split=validation_split,
    seed=seed_train_validation,
    subset="training",
    image_size=(224,224),
    batch_size=batch_size,
    shuffle=shuffle_value)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    labels="inferred",
    label_mode="categorical",
    validation_split=validation_split,
    seed=seed_train_validation,
    subset="validation",
    image_size=(224,224),
    batch_size=batch_size,
    shuffle=shuffle_value)

test_data_dir = pathlib.Path('/kaggle/input/foodx-251/val_set_diviso/val_set_diviso')
shuffle_value = True

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_data_dir,
    labels="inferred",
    label_mode="categorical",
    subset=None,
    image_size=(224,224),
    batch_size=batch_size,
    shuffle=shuffle_value)

test_degraded_data_dir = pathlib.Path('/kaggle/input/foodx-251/val_set_degraded_diviso/val_set_degraded_diviso')
shuffle_value = True
test_degraded_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_degraded_data_dir,
    labels="inferred",
    label_mode="categorical",
    subset=None,
    image_size=(224,224),
    batch_size=batch_size,
    shuffle=shuffle_value)
# Out:
# Found 150600 files belonging to 251 classes.
# Using 120480 files for training.
# Found 150600 files belonging to 251 classes.
# Using 30120 files for validation.
# Found 11993 files belonging to 251 classes.
# Found 11993 files belonging to 251 classes.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 52
#      42 shuffle_value = True
#      43 test_degraded_ds = tf.keras.preprocessing.image_dataset_from_directory(
#      44     test_degraded_data_dir,
#      45     labels="inferred",
#    (...)
#      49     batch_size=batch_size,
#      50     shuffle=shuffle_value)
# ---> 52 test_degraded_ds = test_degraded_ds.map(preprocess)
#
# NameError: name 'preprocess' is not defined

# %%
from keras.applications.resnet50 import ResNet50, preprocess_input

def preprocess(images, labels):
    preprocessed_images = preprocess_input(images)
    return preprocessed_images, labels

train_ds = train_ds.map(preprocess)
val_ds = val_ds.map(preprocess)
test_ds = test_ds.map(preprocess)

test_degraded_ds = test_degraded_ds.map(preprocess)

# %%
base_model = ResNet50(weights='imagenet', include_top=True, input_shape= (224, 224, 3))
#base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 1s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
model = Model(inputs=base_model.input, outputs=base_model.get_layer('avg_pool').output)
last_layer = base_model.get_layer('avg_pool').output
flatten_layer = Flatten()(last_layer)
classification_layer = Dense(251, activation='softmax')(flatten_layer)
model = Model(inputs=model.input, outputs=classification_layer)
#model.summary()

# %%
optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer,  metrics=['accuracy', tf.keras.metrics.TopKCategoricalAccuracy(k=3)])
history = model.fit(train_ds, epochs=20, verbose=1, validation_data=val_ds)
# Out:
# Epoch 1/20
# 471/471 [==============================] - 533s 1s/step - loss: 4.8263 - accuracy: 0.1001 - top_k_categorical_accuracy: 0.1828 - val_loss: 4.2900 - val_accuracy: 0.1713 - val_top_k_categorical_accuracy: 0.2926
# Epoch 2/20
# 471/471 [==============================] - 460s 971ms/step - loss: 4.0296 - accuracy: 0.2202 - top_k_categorical_accuracy: 0.3551 - val_loss: 3.9659 - val_accuracy: 0.2293 - val_top_k_categorical_accuracy: 0.3678
# Epoch 3/20
# 471/471 [==============================] - 458s 966ms/step - loss: 3.7751 - accuracy: 0.2676 - top_k_categorical_accuracy: 0.4130 - val_loss: 3.8252 - val_accuracy: 0.2572 - val_top_k_categorical_accuracy: 0.4032
# Epoch 4/20
# 471/471 [==============================] - 458s 966ms/step - loss: 3.6281 - accuracy: 0.2951 - top_k_categorical_accuracy: 0.4462 - val_loss: 3.7400 - val_accuracy: 0.2743 - val_top_k_categorical_accuracy: 0.4235
# Epoch 5/20
# 471/471 [==============================] - 459s 969ms/step - loss: 3.5247 - accuracy: 0.3165 - top_k_categorical_accuracy: 0.4687 - val_loss: 3.6815 - val_accuracy: 0.2872 - val_top_k_categorical_accuracy: 0.4380
# Epoch 6/20
# 471/471 [==============================] - 458s 966ms/step - loss: 3.3775 - accuracy: 0.3462 - top_k_categorical_accuracy: 0.4987 - val_loss: 3.6011 - val_accuracy: 0.3053 - val_top_k_categorical_accuracy: 0.4574
# Epoch 8/20
# 471/471 [==============================] - 459s 969ms/step - loss: 3.3201 - accuracy: 0.3578 - top_k_categorical_accuracy: 0.5111 - val_loss: 3.5731 - val_accuracy: 0.3102 - val_top_k_categorical_accuracy: 0.4633
# Epoch 9/20
# 471/471 [==============================] - 459s 969ms/step - loss: 3.2699 - accuracy: 0.3683 - top_k_categorical_accuracy: 0.5199 - val_loss: 3.5486 - val_accuracy: 0.3149 - val_top_k_categorical_accuracy: 0.4687
# Epoch 10/20
# 471/471 [==============================] - 457s 965ms/step - loss: 3.2251 - accuracy: 0.3767 - top_k_categorical_accuracy: 0.5293 - val_loss: 3.5275 - val_accuracy: 0.3197 - val_top_k_categorical_accuracy: 0.4739
# Epoch 11/20
# 471/471 [==============================] - 458s 967ms/step - loss: 3.1845 - accuracy: 0.3853 - top_k_categorical_accuracy: 0.5363 - val_loss: 3.5083 - val_accuracy: 0.3241 - val_top_k_categorical_accuracy: 0.4772
# Epoch 12/20
# 471/471 [==============================] - 459s 968ms/step - loss: 3.1474 - accuracy: 0.3930 - top_k_categorical_accuracy: 0.5440 - val_loss: 3.4935 - val_accuracy: 0.3256 - val_top_k_categorical_accuracy: 0.4807
# Epoch 13/20
# 471/471 [==============================] - 459s 968ms/step - loss: 3.1131 - accuracy: 0.3998 - top_k_categorical_accuracy: 0.5507 - val_loss: 3.4808 - val_accuracy: 0.3296 - val_top_k_categorical_accuracy: 0.4814
# Epoch 14/20
# 471/471 [==============================] - 457s 964ms/step - loss: 3.0814 - accuracy: 0.4055 - top_k_categorical_accuracy: 0.5562 - val_loss: 3.4655 - val_accuracy: 0.3321 - val_top_k_categorical_accuracy: 0.4848
# Epoch 15/20
# 471/471 [==============================] - 458s 966ms/step - loss: 3.0516 - accuracy: 0.4116 - top_k_categorical_accuracy: 0.5618 - val_loss: 3.4536 - val_accuracy: 0.3338 - val_top_k_categorical_accuracy: 0.4866
# Epoch 16/20
# 471/471 [==============================] - 458s 967ms/step - loss: 3.0236 - accuracy: 0.4168 - top_k_categorical_accuracy: 0.5666 - val_loss: 3.4430 - val_accuracy: 0.3362 - val_top_k_categorical_accuracy: 0.4890
# Epoch 17/20
# 471/471 [==============================] - 459s 968ms/step - loss: 2.9971 - accuracy: 0.4227 - top_k_categorical_accuracy: 0.5716 - val_loss: 3.4349 - val_accuracy: 0.3367 - val_top_k_categorical_accuracy: 0.4905
# Epoch 18/20
# 471/471 [==============================] - 458s 966ms/step - loss: 2.9721 - accuracy: 0.4270 - top_k_categorical_accuracy: 0.5761 - val_loss: 3.4255 - val_accuracy: 0.3390 - val_top_k_categorical_accuracy: 0.4925
# Epoch 19/20
# 471/471 [==============================] - 459s 966ms/step - loss: 2.9483 - accuracy: 0.4314 - top_k_categorical_accuracy: 0.5802 - val_loss: 3.4167 - val_accuracy: 0.3405 - val_top_k_categorical_accuracy: 0.4936
# Epoch 20/20
# 471/471 [==============================] - 458s 965ms/step - loss: 2.9257 - accuracy: 0.4365 - top_k_categorical_accuracy: 0.5844 - val_loss: 3.4091 - val_accuracy: 0.3419 - val_top_k_categorical_accuracy: 0.4957

# %%
def plot_performance(history):
  fig, ax = plt.subplots(1, 2)
  fig.tight_layout()
  train_acc = history.history['accuracy']
  valid_acc = history.history['val_accuracy']
  train_loss = history.history['loss']
  valid_loss = history.history['val_loss']
  ax[0].set_xlabel('Epoch')
  ax[0].set_ylabel('Loss')
  ax[0].set_title('Loss')
  ax[0].plot(train_loss, label='Training Loss')
  ax[0].plot(valid_loss, label='Validation Loss')
  ax[0].legend()

  ax[1].set_title('Accuracy')
  ax[1].set_xlabel('Epoch')
  ax[1].set_ylabel('Accuracy')
  ax[1].plot(train_acc, label='Training Accuracy')
  ax[1].plot(valid_acc, label='Validation Accuracy')
  ax[1].legend()

  plt.show()

plot_performance(history)

# %%
score = model.evaluate(test_ds, batch_size=256)
print('test loss, test acc:', score)
# Out:
# 47/47 [==============================] - 55s 1s/step - loss: 2.4309 - accuracy: 0.4602 - top_k_categorical_accuracy: 0.6468
# test loss, test acc: [2.4308736324310303, 0.46018511056900024, 0.6467939615249634]

# %%
score = model.evaluate(test_degraded_ds, batch_size=256)
print('test loss, test acc:', score)
# Out:
# 47/47 [==============================] - 49s 899ms/step - loss: 3.0398 - accuracy: 0.3529 - top_k_categorical_accuracy: 0.5233
# test loss, test acc: [3.039759635925293, 0.3528725206851959, 0.5233052372932434]

# %%
model.save('resnet50_degradato_20ep_256batch_adagrad_avg.keras')
